# %%
# Import libraries
import pandas as pd
from ast import literal_eval
from datasets import load_dataset

# %%
# Import data from HuggingFace
dataset = load_dataset("recipe_nlg", split='train', data_dir="../data/recipe_nlg/", trust_remote_code=True)

# %%
# Load data as dataframe and reformat lists
df = pd.read_csv("../data/recipe_nlg/full_dataset.csv", index_col=0, converters={"ingredients": literal_eval,
                                                                                 "directions": literal_eval,
                                                                                 "NER": literal_eval})
df.shape
# Out:
# (2231142, 6)

# %%
df.head()
# Out:
#                    title                                        ingredients  \
# 0    No-Bake Nut Cookies  [1 c. firmly packed brown sugar, 1/2 c. evapor...
# 1  Jewell Ball'S Chicken  [1 small jar chipped beef, cut up, 4 boned chi...
# 2            Creamy Corn  [2 (16 oz.) pkg. frozen corn, 1 (8 oz.) pkg. c...
# 3          Chicken Funny  [1 large whole chicken, 2 (10 1/2 oz.) cans ch...
# 4   Reeses Cups(Candy)    [1 c. peanut butter, 3/4 c. graham cracker cru...
#
#                                           directions  \
# 0  [In a heavy 2-quart saucepan, mix brown sugar,...
# 1  [Place chipped beef on bottom of baking dish.,...
# 2  [In a slow cooker, combine all ingredients. Co...
# 3  [Boil and debone chicken., Put bite size piece...
# 4  [Combine first four ingredients and press in 1...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER
# 0  [brown sugar, milk, vanilla, nuts, butter, bit...
# 1  [beef, chicken breasts, cream of mushroom soup...
# 2  [frozen corn, cream cheese, butter, garlic pow...
# 3  [chicken, chicken gravy, cream of mushroom sou...
# 4  [peanut butter, graham cracker crumbs, butter,...

# %%
df[df['title'].str.len() < 4].head()
# Out:
#       title                                        ingredients  \
# 4071    Mud  [2 c. cold milk, 1 pkg. Jell-O chocolate flavo...
# 15581   Pie  [2 eggs, 2 c. milk (1 1/2 c. to heat, 1/2 c. t...
# 46648   Pie  [Premade graham cracker crust, 1 small pkg. in...
# 51268   Tea  [2 c. water, boiled, 3-inch cinnamon stick, 6 ...
# 55233   Dip  [1 lb. ground round, browned and drained, 1 pk...
#
#                                               directions  \
# 4071   [You will also need a large flowerpot, trowel,...
# 15581  [Mix flour, sugar, salt together. Then add to ...
# 46648  [Combine cream cheese, instant jello and sugar...
# 51268  [In heated tea pot, pour boiled water over tea...
# 55233  [Mix beef, taco seasoning, tomatoes and cheese...
#
#                                                   link    source  \
# 4071   www.cookbooks.com/Recipe-Details.aspx?id=323986  Gathered
# 15581   www.cookbooks.com/Recipe-Details.aspx?id=88188  Gathered
# 46648   www.cookbooks.com/Recipe-Details.aspx?id=60141  Gathered
# 51268  www.cookbooks.com/Recipe-Details.aspx?id=772911  Gathered
# 55233  www.cookbooks.com/Recipe-Details.aspx?id=258779  Gathered
#
#                                                      NER
# 4071             [cold milk, chocolate sandwich cookies]
# 15581  [eggs, milk, sugar, vanilla, flour, salt, butt...
# 46648  [graham cracker crust, instant jello mix, inst...
# 51268  [water, cinnamon, cloves, orange juice, brown ...
# 55233  [ground round, taco seasoning, Ro-Tel, Velveet...

# %%
df[df['ingredients'].str.len() < 3].head()
# Out:
#                               title  \
# 62   Phylis' Pineapple-Banana Salad
# 72                        Dream Pie
# 388                     Herb Butter
# 508                      Raw Gluten
# 530                 Pigs In Blanket
#
#                                            ingredients  \
# 62       [1 large can chunk pineapple, 4 to 5 bananas]
# 72                            [vanilla wafers, butter]
# 388  [2 Tbsp. dried herbs: equal parts of parsley, ...
# 508             [2 lb. whole wheat flour, 1 qt. water]
# 530  [1 pkg. cocktail hot dogs, 5 cans crescent rolls]
#
#                                             directions  \
# 62   [Drain pineapple and reserve juice., Cut banan...
# 72             [Mix vanilla wafer crumbs with butter.]
# 388          [Blend all together and chill overnight.]
# 508  [Mix whole wheat flour with water into a firm ...
# 530  [Wrap wiener, rolls around hot dogs and cook a...
#
#                                                  link    source  \
# 62    www.cookbooks.com/Recipe-Details.aspx?id=682439  Gathered
# 72    www.cookbooks.com/Recipe-Details.aspx?id=621453  Gathered
# 388   www.cookbooks.com/Recipe-Details.aspx?id=503383  Gathered
# 508  www.cookbooks.com/Recipe-Details.aspx?id=1075892  Gathered
# 530   www.cookbooks.com/Recipe-Details.aspx?id=589806  Gathered
#
#                             NER
# 62         [pineapple, bananas]
# 72     [vanilla wafers, butter]
# 388          [herbs, margarine]
# 508  [whole wheat flour, water]
# 530            [crescent rolls]

# %%
df[df['directions'].str.len() < 2].head()
# Out:
#                            title  \
# 2                    Creamy Corn
# 17                Broccoli Salad
# 22  Cuddy Farms Marinated Turkey
# 28      Taco-Filled Green Pepper
# 31                Summer Chicken
#
#                                           ingredients  \
# 2   [2 (16 oz.) pkg. frozen corn, 1 (8 oz.) pkg. c...
# 17  [1 large head broccoli (about 1 1/2 lb.), 10 s...
# 22  [2 c. 7-Up or Sprite, 1 c. vegetable oil, 1 c....
# 28  [1 lb. Ground Beef, 1 pkg. taco seasoning, 1 s...
# 31  [1 pkg. chicken cutlets, 1/2 c. oil, 1/3 c. re...
#
#                                            directions  \
# 2   [In a slow cooker, combine all ingredients. Co...
# 17  [Trim off large leaves of broccoli and remove ...
# 22  [Buy whole turkey breast; remove all skin and ...
# 28  [In a large skillet, brown the ground beef. Dr...
# 31                  [Double recipe for more chicken.]
#
#                                                link    source  \
# 2    www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 17   www.cookbooks.com/Recipe-Details.aspx?id=50992  Gathered
# 22    www.cookbooks.com/Recipe-Details.aspx?id=9449  Gathered
# 28   www.cookbooks.com/Recipe-Details.aspx?id=39004  Gathered
# 31  www.cookbooks.com/Recipe-Details.aspx?id=969444  Gathered
#
#                                                   NER
# 2   [frozen corn, cream cheese, butter, garlic pow...
# 17  [broccoli, bacon, green onions, raisins, mayon...
# 22                 [vegetable oil, soy sauce, garlic]
# 28  [Ground Beef, taco seasoning, beans, onion, sa...
# 31  [chicken cutlets, oil, red vinegar, oregano, g...

# %%
def preprocess(data):
    # Drop recipes that have titles that are too short

# %%
# train test split
dataset.train_test_split(test_size=0.1)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'ingredients', 'directions', 'link', 'source', 'ner'],
#         num_rows: 2008027
#     })
#     test: Dataset({
#         features: ['id', 'title', 'ingredients', 'directions', 'link', 'source', 'ner'],
#         num_rows: 223115
#     })
# })

# %%
from transformers import GPT2Tokenizer, GPT2Config, GPT2LMHeadModel

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

def encode(examples):
    return tokenizer()

# I'm not really doing anything with the config buheret
configuration = GPT2Config.from_pretrained('gpt2', output_hidden_states=False)

# instantiate the model
model = GPT2LMHeadModel.from_pretrained("gpt2", config=configuration)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'ingredients', 'directions', 'link', 'source', 'ner'],
#         num_rows: 2231142
#     })
# })

# %%
ar_df.head()
# Out:
#                                                              title  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  Slow Cooker Chicken and Dumplings
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm      Awesome Slow Cooker Pot Roast
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu               Brown Sugar Meatloaf
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu        Best Chocolate Chip Cookies
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  Homemade Mac and Cheese Casserole
#
#                                                                        ingredients  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  [4 skinless, boneless chicken breast halves AD...
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  [2 (10.75 ounce) cans condensed cream of mushr...
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  [1/2 cup packed brown sugar ADVERTISEMENT, 1/2...
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  [1 cup butter, softened ADVERTISEMENT, 1 cup w...
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  [8 ounces whole wheat rotini pasta ADVERTISEME...
#
#                                                                       instructions  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  Place the chicken, butter, soup, and onion in ...
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  In a slow cooker, mix cream of mushroom soup, ...
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  Preheat oven to 350 degrees F (175 degrees C)....
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  Preheat oven to 350 degrees F (175 degrees C)....
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  Preheat oven to 350 degrees F. Line a 2-quart ...
#
#                                                     picture_link
# rmK12Uau.ntP510KeImX506H6Mr6jTu  55lznCYBbs2mT8BTx6BTkLhynGHzM.S
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  QyrvGdGNMBA2lDdciY0FjKu.77MM0Oe
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  LVW1DI0vtlCrpAhNSEQysE9i/7rJG56
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  0SO5kdWOV94j6EfAVwMMYRM3yNN8eRi
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  YCnbhplMgiraW4rUXcybgSEZinSgljm

# %%
epi_df.head()
# Out:
#                                                                        ingredients  \
# 05zEpbSqcs9E0rcnCJWyZ9OgdH0MLby  [12 egg whites, 12 egg yolks, 1 1/2 cups sugar...
# mF5SZmoqxF4WtIlhLRvzuKk.z6s7P2S  [18 fresh chestnuts, 2 1/2 pounds veal stew me...
# oQV5D7cVbCFwmrDs3pBUv2y.AG0WV26  [2 tablespoons unsalted butter, softened, 4 or...
# Z9seBJWaB5NkSp4DQHDnCAUBTwov/1u  [3/4 pound Stilton, crumbled (about 3 cups) an...
# bB3GxoAplVZeoX3fzWNWyeECtQFxw6G  [2 cups (about 9 1/2 ounces) whole almonds, to...
#
#                                                     picture_link  \
# 05zEpbSqcs9E0rcnCJWyZ9OgdH0MLby                             None
# mF5SZmoqxF4WtIlhLRvzuKk.z6s7P2S                             None
# oQV5D7cVbCFwmrDs3pBUv2y.AG0WV26  3xjktRst3I5lDZ2Z5kTOtqQyzZFFN9u
# Z9seBJWaB5NkSp4DQHDnCAUBTwov/1u                             None
# bB3GxoAplVZeoX3fzWNWyeECtQFxw6G                             None
#
#                                                                       instructions  \
# 05zEpbSqcs9E0rcnCJWyZ9OgdH0MLby  Beat the egg whites until stiff, gradually add...
# mF5SZmoqxF4WtIlhLRvzuKk.z6s7P2S  Preheat oven to 400°F. Using small sharp knife...
# oQV5D7cVbCFwmrDs3pBUv2y.AG0WV26  Preheat the oven to 350°F. Spread the softened...
# Z9seBJWaB5NkSp4DQHDnCAUBTwov/1u  In a food processor blend the Stilton, the cre...
# bB3GxoAplVZeoX3fzWNWyeECtQFxw6G  Position rack in center of oven and preheat to...
#
#                                                                              title
# 05zEpbSqcs9E0rcnCJWyZ9OgdH0MLby                                  Christmas Eggnog
# mF5SZmoqxF4WtIlhLRvzuKk.z6s7P2S                  Veal, Carrot and Chestnut Ragoût
# oQV5D7cVbCFwmrDs3pBUv2y.AG0WV26  Caramelized Bread Pudding with Chocolate and C...
# Z9seBJWaB5NkSp4DQHDnCAUBTwov/1u      Sherried Stilton and Green Peppercorn Spread
# bB3GxoAplVZeoX3fzWNWyeECtQFxw6G                        Almond-Chocolate Macaroons

# %%
fn_df.head()
# Out:
#                                                              title  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  Slow Cooker Chicken and Dumplings
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm      Awesome Slow Cooker Pot Roast
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu               Brown Sugar Meatloaf
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu        Best Chocolate Chip Cookies
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  Homemade Mac and Cheese Casserole
#
#                                                                        ingredients  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  [4 skinless, boneless chicken breast halves AD...
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  [2 (10.75 ounce) cans condensed cream of mushr...
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  [1/2 cup packed brown sugar ADVERTISEMENT, 1/2...
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  [1 cup butter, softened ADVERTISEMENT, 1 cup w...
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  [8 ounces whole wheat rotini pasta ADVERTISEME...
#
#                                                                       instructions  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  Place the chicken, butter, soup, and onion in ...
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  In a slow cooker, mix cream of mushroom soup, ...
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  Preheat oven to 350 degrees F (175 degrees C)....
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  Preheat oven to 350 degrees F (175 degrees C)....
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  Preheat oven to 350 degrees F. Line a 2-quart ...
#
#                                                     picture_link
# rmK12Uau.ntP510KeImX506H6Mr6jTu  55lznCYBbs2mT8BTx6BTkLhynGHzM.S
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  QyrvGdGNMBA2lDdciY0FjKu.77MM0Oe
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  LVW1DI0vtlCrpAhNSEQysE9i/7rJG56
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  0SO5kdWOV94j6EfAVwMMYRM3yNN8eRi
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  YCnbhplMgiraW4rUXcybgSEZinSgljm
